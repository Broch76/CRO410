# %%
from numpy import *
from scipy.optimize import fsolve
from scipy.integrate import odeint
from matplotlib import pyplot as plt
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
thiele = linspace(0.01, 50, 101)
eta    = 3*(thiele*(1/tanh(thiele)) -1) / (thiele**2)

# %%
plt.plot(log10(thiele),log10(eta),'-', label = 'Eta vs Thiele')
#plt.axis([0,500, 0, 1.5])
#plt.legend(loc='best')
plt.ylabel("Eta")
plt.xlabel("Thiele")
plt.show()
